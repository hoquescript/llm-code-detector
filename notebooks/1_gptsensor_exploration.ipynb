# %%
import pandas as pd
import numpy as np
import torch

# Set pandas to show full column content (so we can see the code snippets later)
pd.set_option('display.max_colwidth', None)
# Read data
df = pd.read_json("../data/codegptsensor/python/train.jsonl", lines=True)

# %%
# Check the structure
print("Shape:", df.shape)
print("\nColumn names:")
print(df.columns.tolist())

# Look at first few rows
print("\nFirst 3 rows:")
print(df.head(3))
# Out:
# Shape: (230806, 4)
#
# Column names:
# ['index', 'code', 'contrast', 'label']
#
# First 3 rows:
#       index  \
# 0  gp223799
# 1  gp118367
# 2  gp102957
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  code  \
# ...
